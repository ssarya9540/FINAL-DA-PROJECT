# %% [markdown]
# # 1). Read csv data

# %%
import pandas as pd 
import numpy as np

# %%
cricket=pd.read_csv(r'/Users/shubhamkumar/Desktop/cricket-2.csv',encoding='latin1')
cricket
# Out:
#                          Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0          SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3       ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4    DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
# ..                          ...        ...  ...   ...  ..    ...   ...    ...
# 74            CG Greenidge (WI)  1975-1991  128   127  13   5134  133*  45.03
# 75          Misbah-ul-Haq (PAK)  2002-2015  162   149  31   5122   96*  43.40
# 76         PD Collingwood (ENG)  2001-2011  197   181  37   5092  120*  35.36
# 77              A Symonds (AUS)  1998-2009  198   161  33   5088   156  39.75
# 78      Abdul Razzaq (Asia/PAK)  1996-2011  265   228  57   5080   112  29.70
#
#        BF     SR  100  50   0  Remarks
# 0   21367  86.23   49  96  20      NaN
# 1   18048  78.86   25  93  15      NaN
# 2   17046  80.39   30  82  20      NaN
# 3   14725  91.20   28  68  34      NaN
# 4   16020  78.96   19  77  28      NaN
# ..    ...    ...  ...  ..  ..      ...
# 74   7908  64.92   11  31   3      NaN
# 75   6945  73.75    0  42   6      NaN
# 76   6614  76.98    5  26   7      NaN
# 77   5504  92.44    6  30  15      NaN
# 78   6252  81.25    3  23  14      NaN
#
# [79 rows x 14 columns]

# %%
cricket.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0  Remarks
# 0  21367  86.23   49  96  20      NaN
# 1  18048  78.86   25  93  15      NaN
# 2  17046  80.39   30  82  20      NaN
# 3  14725  91.20   28  68  34      NaN
# 4  16020  78.96   19  77  28      NaN

# %% [markdown]
# # 2). To check a size of data

# %%
cricket.shape
# Out:
# (79, 14)

# %% [markdown]
# # 3). Information about data frame(columns, column labels, column data types, memory usage, range index,null,not null)

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Player   79 non-null     object
#  1   Span     79 non-null     object
#  2   Mat      79 non-null     int64
#  3   Inns     79 non-null     int64
#  4   NO       79 non-null     int64
#  5   Runs     79 non-null     int64
#  6   HS       79 non-null     object
#  7   Ave      79 non-null     float64
#  8   BF       79 non-null     int64
#  9   SR       79 non-null     float64
#  10  100      79 non-null     int64
#  11  50       79 non-null     int64
#  12  0        79 non-null     int64
#  13  Remarks  0 non-null      float64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 8.8+ KB

# %% [markdown]
# # 4). Check in cricket data has null value or not null value

# %%
cricket.isnull()
# Out:
#     Player   Span    Mat   Inns     NO   Runs     HS    Ave     BF     SR  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 74   False  False  False  False  False  False  False  False  False  False
# 75   False  False  False  False  False  False  False  False  False  False
# 76   False  False  False  False  False  False  False  False  False  False
# 77   False  False  False  False  False  False  False  False  False  False
# 78   False  False  False  False  False  False  False  False  False  False
#
#       100     50      0  Remarks
# 0   False  False  False     True
# 1   False  False  False     True
# 2   False  False  False     True
# 3   False  False  False     True
# 4   False  False  False     True
# ..    ...    ...    ...      ...
# 74  False  False  False     True
# 75  False  False  False     True
# 76  False  False  False     True
# 77  False  False  False     True
# 78  False  False  False     True
#
# [79 rows x 14 columns]

# %% [markdown]
# #from this code we can identify the undefined column has null values in cricket data

# %% [markdown]
# # 5). Now to Checking how many columns have null values

# %%
[col for col in cricket.columns if cricket[col].isnull().sum() > 0]
# Out:
# ['Remarks']

# %% [markdown]
# #means in cricket data only one column has null values

# %% [markdown]
# # 6). To drop the null values

# %%
unique_cols =  [x for x in cricket.columns if cricket[x].nunique()==1] 
print(unique_cols)
cricket.drop(unique_cols,axis=1,inplace=True)
cricket.columns
# Out:
# []
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', 'Remarks'],
#       dtype='object')

# %%
cricket.drop('Remarks',axis=1,inplace=True)
cricket.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %% [markdown]
# #Here we deleted a all Null values from cricket data by using drop method and given inplace is true. Now we got a clear data to next preceed.

# %%
cricket.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %% [markdown]
# #This is our not null(clear) data

# %% [markdown]
# # 7). define statistical values of data using describe method(summery check)

# %%
cricket.describe().T
# Out:
#       count         mean          std      min       25%      50%        75%  \
# Mat    79.0   245.075949    74.211716   128.00   188.000   232.00    281.500
# Inns   79.0   230.544304    70.321022   127.00   177.000   217.00    261.500
# NO     79.0    30.037975    14.421710     4.00    17.500    29.00     40.000
# Runs   79.0  7618.139241  2551.873313  5080.00  5759.000  6798.00   8739.500
# Ave    79.0    38.523291     5.919093    23.57    34.600    37.87     41.845
# BF     79.0  9684.455696  3193.835825  5504.00  7393.500  9134.00  10976.000
# SR     79.0    79.295316     9.925307    60.57    73.725    77.73     85.180
# 100    79.0    11.556962     8.092014     0.00     6.000    10.00     15.500
# 50     79.0    46.443038    16.351701    23.00    34.500    42.00     54.000
# 0      79.0    13.253165     5.925755     3.00     9.000    13.00     16.000
#
#            max
# Mat     463.00
# Inns    452.00
# NO       70.00
# Runs  18426.00
# Ave      53.94
# BF    21367.00
# SR      117.00
# 100      49.00
# 50       96.00
# 0        34.00

# %% [markdown]
# #here we defined the all summery of data

# %% [markdown]
# # 8). To Data Transformation

# %%
cricket[['Start', 'Last']] = cricket['Span'].str.split('-', n=1, expand=True)
cricket.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0 Start  Last
# 0  21367  86.23   49  96  20  1989  2012
# 1  18048  78.86   25  93  15  2000  2015
# 2  17046  80.39   30  82  20  1995  2012
# 3  14725  91.20   28  68  34  1989  2011
# 4  16020  78.96   19  77  28  1998  2015

# %% [markdown]
# #here we seperated the Span coloumn into two different coloumns start and Last

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  79 non-null     object
#  1   Span    79 non-null     object
#  2   Mat     79 non-null     int64
#  3   Inns    79 non-null     int64
#  4   NO      79 non-null     int64
#  5   Runs    79 non-null     int64
#  6   HS      79 non-null     object
#  7   Ave     79 non-null     float64
#  8   BF      79 non-null     int64
#  9   SR      79 non-null     float64
#  10  100     79 non-null     int64
#  11  50      79 non-null     int64
#  12  0       79 non-null     int64
#  13  Start   79 non-null     object
#  14  Last    79 non-null     object
# dtypes: float64(2), int64(8), object(5)
# memory usage: 9.4+ KB

# %% [markdown]
# #Here we can see the Start and Last coloumn are not in integer.

# %% [markdown]
# # 9). To convert Start and Last column from object to integer

# %%
cricket[['Start','Last']]=cricket[['Start','Last']].astype(int)

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  79 non-null     object
#  1   Span    79 non-null     object
#  2   Mat     79 non-null     int64
#  3   Inns    79 non-null     int64
#  4   NO      79 non-null     int64
#  5   Runs    79 non-null     int64
#  6   HS      79 non-null     object
#  7   Ave     79 non-null     float64
#  8   BF      79 non-null     int64
#  9   SR      79 non-null     float64
#  10  100     79 non-null     int64
#  11  50      79 non-null     int64
#  12  0       79 non-null     int64
#  13  Start   79 non-null     int32
#  14  Last    79 non-null     int32
# dtypes: float64(2), int32(2), int64(8), object(3)
# memory usage: 8.8+ KB

# %% [markdown]
# #Now the Start and Last coloumn are in integer type

# %% [markdown]
# # 10). Add the coloumn in data

# %%
cricket['Exp']=cricket['Last']-cricket['Start']
cricket
# Out:
#                          Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0          SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2          RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3       ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4    DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
# ..                          ...        ...  ...   ...  ..    ...   ...    ...
# 74            CG Greenidge (WI)  1975-1991  128   127  13   5134  133*  45.03
# 75          Misbah-ul-Haq (PAK)  2002-2015  162   149  31   5122   96*  43.40
# 76         PD Collingwood (ENG)  2001-2011  197   181  37   5092  120*  35.36
# 77              A Symonds (AUS)  1998-2009  198   161  33   5088   156  39.75
# 78      Abdul Razzaq (Asia/PAK)  1996-2011  265   228  57   5080   112  29.70
#
#        BF     SR  100  50   0  Start  Last  Exp
# 0   21367  86.23   49  96  20   1989  2012   23
# 1   18048  78.86   25  93  15   2000  2015   15
# 2   17046  80.39   30  82  20   1995  2012   17
# 3   14725  91.20   28  68  34   1989  2011   22
# 4   16020  78.96   19  77  28   1998  2015   17
# ..    ...    ...  ...  ..  ..    ...   ...  ...
# 74   7908  64.92   11  31   3   1975  1991   16
# 75   6945  73.75    0  42   6   2002  2015   13
# 76   6614  76.98    5  26   7   2001  2011   10
# 77   5504  92.44    6  30  15   1998  2009   11
# 78   6252  81.25    3  23  14   1996  2011   15
#
# [79 rows x 16 columns]

# %% [markdown]
# #from this code we got a total year of play cricket for each player

# %% [markdown]
# # 11). to delete not required columns

# %%
cricket=cricket.drop(['Span','Start','Last'],axis=1)

# %%
cricket.head()
# Out:
#                         Player  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0         SR Tendulkar (INDIA)  463   452  41  18426  200*  44.83  21367
# 1  KC Sangakkara (Asia/ICC/SL)  404   380  41  14234   169  41.98  18048
# 2         RT Ponting (AUS/ICC)  375   365  39  13704   164  42.03  17046
# 3      ST Jayasuriya (Asia/SL)  445   433  18  13430   189  32.36  14725
# 4   DPMD Jayawardene (Asia/SL)  448   418  39  12650   144  33.37  16020
#
#       SR  100  50   0  Exp
# 0  86.23   49  96  20   23
# 1  78.86   25  93  15   15
# 2  80.39   30  82  20   17
# 3  91.20   28  68  34   22
# 4  78.96   19  77  28   17

# %% [markdown]
# #Here we deleted the unnecessory column(Start,Last)

# %%
 x=cricket.pop('Exp')

# %%
cricket.head()
# Out:
#                         Player  Mat  Inns  NO   Runs    HS    Ave     BF  \
# 0         SR Tendulkar (INDIA)  463   452  41  18426  200*  44.83  21367
# 1  KC Sangakkara (Asia/ICC/SL)  404   380  41  14234   169  41.98  18048
# 2         RT Ponting (AUS/ICC)  375   365  39  13704   164  42.03  17046
# 3      ST Jayasuriya (Asia/SL)  445   433  18  13430   189  32.36  14725
# 4   DPMD Jayawardene (Asia/SL)  448   418  39  12650   144  33.37  16020
#
#       SR  100  50   0
# 0  86.23   49  96  20
# 1  78.86   25  93  15
# 2  80.39   30  82  20
# 3  91.20   28  68  34
# 4  78.96   19  77  28

# %%
cricket.insert(2,'Exp',x)

# %%
cricket.head()
# Out:
#                         Player  Mat  Exp  Inns  NO   Runs    HS    Ave     BF  \
# 0         SR Tendulkar (INDIA)  463   23   452  41  18426  200*  44.83  21367
# 1  KC Sangakkara (Asia/ICC/SL)  404   15   380  41  14234   169  41.98  18048
# 2         RT Ponting (AUS/ICC)  375   17   365  39  13704   164  42.03  17046
# 3      ST Jayasuriya (Asia/SL)  445   22   433  18  13430   189  32.36  14725
# 4   DPMD Jayawardene (Asia/SL)  448   17   418  39  12650   144  33.37  16020
#
#       SR  100  50   0
# 0  86.23   49  96  20
# 1  78.86   25  93  15
# 2  80.39   30  82  20
# 3  91.20   28  68  34
# 4  78.96   19  77  28

# %% [markdown]
# #here we change the actual position of coloumn Exp from index-2 position

# %% [markdown]
# # 12). Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Barplot

# %%
# graph1)
plt.figure(figsize=(30,5))
mat=cricket[['Player','Mat']].sort_values('Mat',ascending=False)
ax=sns.barplot(x='Player',y='Mat',data=mat)
ax.set(xlabel='',ylabel='Match played')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #plt.figure(figsize=(30,5)) This line sets the size of the chart.(30=30inch width and 5=5inch height)
# #mat=cricket[['Player','Mat']].sort_values('Mat',ascending=False) In this line we selected player and mat coloumns and coloumn Mat arranged into decending order and assigned it into new coloumn Mat.
# #ax=sns.barplot(x='Player',y='Mat',data=mat) in this line the 'Player' column is plotted on the x-axis and the 'Mat' column is plotted on the y-axis.
# #ax.set(xlabel='',ylabel='Match played') here we describe the lebel of y-axis='Match played' and x-axis= empty string.
# #plt.xticks(rotation=90)= here Rotates the x-axis labels by 90 degrees
# #plt.show()= at last display the result

# %%
#*Result of that graph1)*= Sachin Tendulkar is the most match played batsman,and CG Greenidge is the less match played batsman.

# %%
#graph2)
plt.figure(figsize=(30,5))
runs=cricket[['Player','Runs']].sort_values('Runs',ascending=False)
ax=sns.barplot(x='Player',y='Runs',data=runs)
ax.set(xlabel='',ylabel='runs')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #*Result of graph2)*= Sachin Tendulkar is the most run scorer and Abdul Razzaq is the less run scorer in all matches.

# %%
#graph3)
plt.figure(figsize=(30,5))
inns=cricket[['Player','Inns']].sort_values('Inns',ascending=False)
ax=sns.barplot(x='Player',y='Inns',data=inns)
ax.set(xlabel='',ylabel='INNINGS')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #*Result of graph3)*=Sachin Tendulakar is the most innings played and CG Greenidge(WI) is the less innings played.

# %%
#graph 4).
plt.figure(figsize=(30,5))
no=cricket[['Player','NO']].sort_values('NO',ascending=False)
ax=sns.barplot(x='Player',y='NO',data=no)
ax.set(xlabel='',ylabel='Not outs')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #*Result of graph4)*= MS Dhoni is the not out in most of matches and Tamim Iqbal is not out in less of matches.

# %%
cricket.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  79 non-null     object
#  1   Span    79 non-null     object
#  2   Mat     79 non-null     int64
#  3   Inns    79 non-null     int64
#  4   NO      79 non-null     int64
#  5   Runs    79 non-null     int64
#  6   HS      79 non-null     object
#  7   Ave     79 non-null     float64
#  8   BF      79 non-null     int64
#  9   SR      79 non-null     float64
#  10  100     79 non-null     int64
#  11  50      79 non-null     int64
#  12  0       79 non-null     int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 8.1+ KB

# %%
cricket.HS=cricket.HS.str.extract('(\d+)')
cricket.HS=cricket.HS.astype(int)

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  79 non-null     object
#  1   Span    79 non-null     object
#  2   Mat     79 non-null     int64
#  3   Inns    79 non-null     int64
#  4   NO      79 non-null     int64
#  5   Runs    79 non-null     int64
#  6   HS      79 non-null     int64
#  7   Ave     79 non-null     float64
#  8   BF      79 non-null     int64
#  9   SR      79 non-null     float64
#  10  100     79 non-null     int64
#  11  50      79 non-null     int64
#  12  0       79 non-null     int64
# dtypes: float64(2), int64(9), object(2)
# memory usage: 8.1+ KB

# %%
#graph 5)
#cricket.HS=cricket.HS.str.extract('(\d+)')
#cricket.HS=cricket.HS.astype(int)

plt.figure(figsize=(30,5))
HS=cricket[['Player','HS']].sort_values('HS',ascending=False)
ax=sns.barplot(x='Player',y='HS',data=HS)
ax.set(xlabel='',ylabel='High score')
plt.xticks(rotation=90)
plt.show()
plt.savefig('output.png')

# %% [markdown]
# #*Result of graph 5)*=RG Sharma is the highest scorer of the perticular matches and Misbah-ul-Haq(Pak) is lowest score of the perticular matches.

# %% [markdown]
# ## Heatmap

# %%
cricket.head()
# Out:
#                         Player       Span  Mat  Inns  NO   Runs   HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234  169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704  164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430  189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650  144  33.37
#
#       BF     SR  100  50   0
# 0  21367  86.23   49  96  20
# 1  18048  78.86   25  93  15
# 2  17046  80.39   30  82  20
# 3  14725  91.20   28  68  34
# 4  16020  78.96   19  77  28

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cricket.corr(),annot=True,cmap='Blues')
plt.show()

# %% [markdown]
# #Result of heatmap=Basically heatmap is use for the showing the correlation of data.

# %%
cricket_drop=cricket.copy()
player=cricket_drop.pop('Player')

# %%
cricket_drop
# Out:
#     Mat  Exp  Inns  NO   Runs   HS    Ave     BF     SR  100  50   0
# 0   463   23   452  41  18426  200  44.83  21367  86.23   49  96  20
# 1   404   15   380  41  14234  169  41.98  18048  78.86   25  93  15
# 2   375   17   365  39  13704  164  42.03  17046  80.39   30  82  20
# 3   445   22   433  18  13430  189  32.36  14725  91.20   28  68  34
# 4   448   17   418  39  12650  144  33.37  16020  78.96   19  77  28
# ..  ...  ...   ...  ..    ...  ...    ...    ...    ...  ...  ..  ..
# 74  128   16   127  13   5134  133  45.03   7908  64.92   11  31   3
# 75  162   13   149  31   5122   96  43.40   6945  73.75    0  42   6
# 76  197   10   181  37   5092  120  35.36   6614  76.98    5  26   7
# 77  198   11   161  33   5088  156  39.75   5504  92.44    6  30  15
# 78  265   15   228  57   5080  112  29.70   6252  81.25    3  23  14
#
# [79 rows x 12 columns]

# %% [markdown]
# #Here we delete the column player by using pop and save the data as n new variable cricket_drop

# %% [markdown]
# # 13). Model building

# %% [markdown]
# ### Rescaling= #rescaling is a common data preprocessing technique that can help to make data more comparable, interpretable, and suitable for analysis or modeling

# %%
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
cricket_scaled=scaler.fit_transform(cricket_drop)

# %%
cricket_scaled
# Out:
# array([[ 2.95528204e+00,  2.81278702e+00,  3.16933340e+00,
#          7.64962749e-01,  4.26232808e+00,  1.63244320e+00,
#          1.07229395e+00,  3.68121424e+00,  7.03151526e-01,
#          4.65672622e+00,  3.05005720e+00,  1.14583653e+00],
#        [ 2.15517925e+00,  3.80938324e-01,  2.13891509e+00,
#          7.64962749e-01,  2.60911662e+00,  6.35223595e-01,
#          5.87724608e-01,  2.63538469e+00, -4.41394951e-02,
#          1.67188751e+00,  2.86541772e+00,  2.96670622e-01],
#        [ 1.76190839e+00,  9.88900497e-01,  1.92424461e+00,
#          6.25396797e-01,  2.40009894e+00,  4.74381724e-01,
#          5.96225824e-01,  2.31965067e+00,  1.10996904e-01,
#          2.29372891e+00,  2.18840630e+00,  1.14583653e+00],
#        [ 2.71118288e+00,  2.50880593e+00,  2.89741746e+00,
#         -8.40045698e-01,  2.29204075e+00,  1.27859108e+00,
#         -1.04790945e+00,  1.58829472e+00,  1.20709133e+00,
#          2.04499235e+00,  1.32675540e+00,  3.52350108e+00],
#        [ 2.75186607e+00,  9.88900497e-01,  2.68274698e+00,
#          6.25396797e-01,  1.98442984e+00, -1.68985764e-01,
#         -8.76184872e-01,  1.99635416e+00, -3.39998611e-02,
#          9.25677829e-01,  1.88067384e+00,  2.50450199e+00],
#        [ 1.80259158e+00,  6.84919410e-01,  1.70957413e+00,
#          1.60235846e+00,  1.62515607e+00, -3.94164385e-01,
#          1.69464756e-01,  1.93081256e+00, -5.12590583e-01,
#         -1.93636689e-01,  2.24995279e+00,  1.14583653e+00],
#          8.29159156e-01, -8.63212931e-01, -5.62274789e-01,
#         -1.43731949e+00, -2.73453404e-01, -1.23182802e+00],
#        [-6.51961035e-01, -1.13896711e+00, -7.09046639e-01,
#          4.85830845e-01, -9.96241019e-01, -9.41026749e-01,
#         -5.37836456e-01, -9.67512293e-01, -2.34764613e-01,
#         -8.15478087e-01, -1.25819729e+00, -1.06199484e+00],
#        [-6.38399970e-01, -8.34986023e-01, -9.95273948e-01,
#          2.06698941e-01, -9.97818511e-01,  2.17034728e-01,
#          2.08570352e-01, -1.31727752e+00,  1.33282279e+00,
#         -6.91109807e-01, -1.01201131e+00,  2.96670622e-01],
#        [ 2.70191329e-01,  3.80938324e-01, -3.64124615e-02,
#          1.88149036e+00, -1.00097349e+00, -1.19837374e+00,
#         -1.50017416e+00, -1.08157987e+00,  1.98197756e-01,
#         -1.06421465e+00, -1.44283676e+00,  1.26837440e-01]])

# %%
cricket.columns
# Out:
# Index(['Player', 'Mat', 'Exp', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0'],
#       dtype='object')

# %%
cricket_cricket1=pd.DataFrame(cricket_scaled,columns=['Mat', 'Exp', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
       '100', '50', '0'])
cricket_cricket1.head()
# Out:
#         Mat       Exp      Inns        NO      Runs        HS       Ave  \
# 0  2.955282  2.812787  3.169333  0.764963  4.262328  1.632443  1.072294
# 1  2.155179  0.380938  2.138915  0.764963  2.609117  0.635224  0.587725
# 2  1.761908  0.988900  1.924245  0.625397  2.400099  0.474382  0.596226
# 3  2.711183  2.508806  2.897417 -0.840046  2.292041  1.278591 -1.047909
# 4  2.751866  0.988900  2.682747  0.625397  1.984430 -0.168986 -0.876185
#
#          BF        SR       100        50         0
# 0  3.681214  0.703152  4.656726  3.050057  1.145837
# 1  2.635385 -0.044139  1.671888  2.865418  0.296671
# 2  2.319651  0.110997  2.293729  2.188406  1.145837
# 3  1.588295  1.207091  2.044992  1.326755  3.523501
# 4  1.996354 -0.034000  0.925678  1.880674  2.504502

# %% [markdown]
# #here we created a new DataFrame with renamed columns and scaled data, which can be used for further analysis.

# %% [markdown]
# ### Clustering

# %%
from sklearn.cluster import KMeans

# %%
#elbow 
clusters=list(range(2,8))
ssd=[]
for num_clusters in clusters:
    model_clus=KMeans(n_clusters=num_clusters,random_state=50,max_iter=150)
    model_clus.fit(cricket_cricket1)
    ssd.append(model_clus.inertia_)
plt.plot(clusters,ssd);

# %%
cluster=KMeans(n_clusters=4,random_state=15)
cluster.fit(cricket_cricket1)
# Out:
# KMeans(n_clusters=4, random_state=15)

# %% [markdown]
# #here we defined clusters of our cricket data

# %% [markdown]
# ### Silhouette score analysis to find the ideal number of clusters for K-means clustering

# %%
#avg,sr,no

# %%
from sklearn.metrics import silhouette_score

# %%
# Silhouette score analysis to find the ideal number of clusters for K-means clustering

range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50,random_state= 0)
    kmeans.fit(cricket_cricket1)
    
    cluster_labels = kmeans.labels_
    
    
    silhouette_avg = silhouette_score(cricket_cricket1, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.3136820966012298
# For n_clusters=3, the silhouette score is 0.19858564891531444
# For n_clusters=4, the silhouette score is 0.20841209056492216
# For n_clusters=5, the silhouette score is 0.18893894316607288
# For n_clusters=6, the silhouette score is 0.17582453875285378
# For n_clusters=7, the silhouette score is 0.18507856072779297
# For n_clusters=8, the silhouette score is 0.18406940520110662

# %%
cluster_labels
# Out:
# array([3, 3, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 5, 2, 2, 7, 2, 5, 5, 2, 5, 2,
#        2, 5, 5, 7, 5, 6, 0, 4, 0, 0, 0, 0, 7, 0, 1, 1, 4, 1, 1, 0, 7, 0,
#        0, 0, 4, 0, 1, 1, 5, 1, 1, 4, 1, 1, 4, 4, 4, 7, 1, 4, 4, 7, 4, 7,
#        1, 4, 4, 1, 1, 1, 1, 0, 1, 4, 4, 4, 0])

# %%
cricket['Cluster_Id']=cluster_labels
cricket
# Out:
#                          Player  Mat  Exp  Inns  NO   Runs   HS    Ave     BF  \
# 0          SR Tendulkar (INDIA)  463   23   452  41  18426  200  44.83  21367
# 1   KC Sangakkara (Asia/ICC/SL)  404   15   380  41  14234  169  41.98  18048
# 2          RT Ponting (AUS/ICC)  375   17   365  39  13704  164  42.03  17046
# 3       ST Jayasuriya (Asia/SL)  445   22   433  18  13430  189  32.36  14725
# 4    DPMD Jayawardene (Asia/SL)  448   17   418  39  12650  144  33.37  16020
# ..                          ...  ...  ...   ...  ..    ...  ...    ...    ...
# 74            CG Greenidge (WI)  128   16   127  13   5134  133  45.03   7908
# 75          Misbah-ul-Haq (PAK)  162   13   149  31   5122   96  43.40   6945
# 76         PD Collingwood (ENG)  197   10   181  37   5092  120  35.36   6614
# 77              A Symonds (AUS)  198   11   161  33   5088  156  39.75   5504
# 78      Abdul Razzaq (Asia/PAK)  265   15   228  57   5080  112  29.70   6252
#
#        SR  100  50   0  Cluster_Id
# 0   86.23   49  96  20           3
# 1   78.86   25  93  15           3
# 2   80.39   30  82  20           3
# 3   91.20   28  68  34           3
# 4   78.96   19  77  28           3
# ..    ...  ...  ..  ..         ...
# 74  64.92   11  31   3           1
# 75  73.75    0  42   6           4
# 76  76.98    5  26   7           4
# 77  92.44    6  30  15           4
# 78  81.25    3  23  14           0
#
# [79 rows x 14 columns]

# %% [markdown]
# ## Scatterplot

# %%
plt.figure(figsize=(20,15))
plt.subplot(3,1,1)
sns.scatterplot(x='Ave',y='NO',hue='Cluster_Id',data=cricket,legend='full',palette='Set1')
plt.subplot(3,1,2)
sns.scatterplot(x='Ave',y='SR',hue='Cluster_Id',data=cricket,legend='full',palette='Set1')
plt.subplot(3,1,3)
sns.scatterplot(x='NO',y='SR',hue='Cluster_Id',data=cricket,legend='full',palette='Set1')
plt.show()

# %%
cricket[cricket['Cluster_Id']==0].sort_values(by=['NO','Ave','SR'],ascending=[False,False,False]).head()
# Out:
#                       Player  Mat  Exp  Inns  NO  Runs   HS    Ave     BF  \
# 30            SR Waugh (AUS)  325   16   288  58  7569  120  32.90   9971
# 78   Abdul Razzaq (Asia/PAK)  265   15   228  57  5080  112  29.70   6252
# 31          A Ranatunga (SL)  269   17   255  47  7456  131  35.84   9571
# 32       Javed Miandad (PAK)  233   21   218  41  7381  119  41.70  11014
# 45           AR Border (AUS)  273   15   252  39  6524  127  30.62   9134
#
#        SR  100  50   0  Cluster_Id
# 30  75.91    3  45  15           0
# 78  81.25    3  23  14           0
# 31  77.90    4  49  18           0
# 32  67.01    8  50   8           0
# 45  71.42    3  39  11           0

# %%
cricket[cricket['Cluster_Id']==1].sort_values(by=['NO','Ave','SR'],ascending=[False,False,False]).head()
# Out:
#              Player  Mat  Exp  Inns  NO  Runs   HS    Ave    BF     SR  100  \
# 72  MN Samuels (WI)  187   16   177  26  5180  133  34.30  6794  76.24   10
# 51   DM Jones (AUS)  164   10   161  25  6068  145  44.61  8362  72.56    7
# 39   G Kirsten (SA)  185   10   185  19  6798  188  40.95  9436  72.04   13
# 52    DC Boon (AUS)  181   11   177  16  5964  122  37.04  9157  65.13    5
# 40   A Flower (ZIM)  213   11   208  16  6786  145  35.34  9097  74.59    4
#
#     50   0  Cluster_Id
# 72  28  10           1
# 51  46   6           1
# 39  45  11           1
# 52  37   6           1
# 40  55  13           1

# %%
cricket[cricket['Cluster_Id']==2].sort_values(by=['NO','Ave','SR'],ascending=[False,False,False]).head()
# Out:
#                        Player  Mat  Exp  Inns  NO   Runs   HS    Ave     BF  \
# 13      MS Dhoni (Asia/INDIA)  295   13   255  70   9496  183  51.32  10706
# 14       M Azharuddin (INDIA)  334   15   308  54   9378  153  36.92  12669
# 6      JH Kallis (Afr/ICC/SA)  328   18   314  53  11579  139  44.36  15885
# 5   Inzamam-ul-Haq (Asia/PAK)  378   16   350  53  11739  137  39.52  15812
# 10            TM Dilshan (SL)  330   17   303  41  10290  161  39.27  11933
#
#        SR  100  50   0  Cluster_Id
# 13  88.69   10  64   8           2
# 14  74.02    7  58   9           2
# 6   72.89   17  86  17           2
# 5   74.24   10  83  20           2
# 10  86.23   22  47  11           2

# %%
cricket[cricket['Cluster_Id']==3].sort_values(by=['NO','Ave','SR'],ascending=[False,False,False]).head()
# Out:
#                         Player  Mat  Exp  Inns  NO   Runs   HS    Ave     BF  \
# 0         SR Tendulkar (INDIA)  463   23   452  41  18426  200  44.83  21367
# 1  KC Sangakkara (Asia/ICC/SL)  404   15   380  41  14234  169  41.98  18048
# 2         RT Ponting (AUS/ICC)  375   17   365  39  13704  164  42.03  17046
# 4   DPMD Jayawardene (Asia/SL)  448   17   418  39  12650  144  33.37  16020
# 3      ST Jayasuriya (Asia/SL)  445   22   433  18  13430  189  32.36  14725
#
#       SR  100  50   0  Cluster_Id
# 0  86.23   49  96  20           3
# 1  78.86   25  93  15           3
# 2  80.39   30  82  20           3
# 4  78.96   19  77  28           3
# 3  91.20   28  68  34           3

# %%
cricket[cricket['Cluster_Id']==4].sort_values(by=['NO','Ave','SR'],ascending=[False,False,False]).head()
# Out:
#               Player  Mat  Exp  Inns  NO  Runs   HS    Ave     BF     SR  100  \
# 38    MG Bevan (AUS)  232   10   196  67  6912  108  53.58   9320  74.16    6
# 68   DR Martyn (AUS)  208   14   182  51  5346  144  40.80   6877  77.73    5
# 53    JN Rhodes (SA)  245   11   220  51  5935  121  35.11   7336  80.90    2
# 64  MEK Hussey (AUS)  185    8   157  44  5442  109  48.15   6243  87.16    3
# 29   MJ Clarke (AUS)  245   12   223  44  7981  130  44.58  10104  78.98    8
#
#     50   0  Cluster_Id
# 38  46   5           4
# 68  37  10           4
# 53  33  12           4
# 64  39   3           4
# 29  58  10           4

# %%
cricket[cricket['Cluster_Id']==5].sort_values(by=['NO','Ave','SR'],ascending=[False,False,False]).head()
# Out:
#                        Player  Mat  Exp  Inns  NO  Runs   HS    Ave     BF  \
# 20  Yuvraj Singh (Asia/INDIA)  304   17   278  40  8701  150  36.55   9924
# 50           BB McCullum (NZ)  260   14   228  28  6083  166  30.41   6312
# 23             ME Waugh (AUS)  244   14   236  20  8500  173  39.35  11053
# 18          Saeed Anwar (PAK)  247   14   244  19  8824  194  39.21  10938
# 17          CH Gayle (ICC/WI)  269   16   264  17  9221  215  37.33  10834
#
#        SR  100  50   0  Cluster_Id
# 20  87.67   14  52  18           5
# 50  96.37    5  32  20           5
# 23  76.90   18  50  16           5
# 18  80.67   20  43  15           5
# 17  85.11   22  47  23           5

# %%
cricket[cricket['Cluster_Id']==6].sort_values(by=['NO','Ave','SR'],ascending=[False,False,False]).head()
# Out:
#                           Player  Mat  Exp  Inns  NO  Runs   HS    Ave    BF  \
# 27  Shahid Afridi (Asia/ICC/PAK)  398   19   369  27  8064  124  23.57  6892
#
#        SR  100  50   0  Cluster_Id
# 27  117.0    6  39  30           6

# %%
cricket[cricket['Cluster_Id']==7].sort_values(by=['NO','Ave','SR'],ascending=[False,False,False]).head()
# Out:
#                      Player  Mat  Exp  Inns  NO  Runs   HS    Ave    BF  \
# 15  AB de Villiers (Afr/SA)  222   12   213  39  9319  162  53.55  9295
# 25          V Kohli (INDIA)  188    9   180  29  8146  183  53.94  8952
# 59          SR Watson (AUS)  190   13   169  27  5757  185  40.54  6365
# 42        IVA Richards (WI)  187   16   167  24  6721  189  47.00  7451
# 65        RG Sharma (INDIA)  158   10   152  24  5435  264  42.46  6427
#
#         SR  100  50   0  Cluster_Id
# 15  100.25   24  53   7           7
# 25   90.99   27  43  11           7
# 59   90.44    9  33  12           7
# 42   90.20   11  45   7           7
# 65   84.56   11  31  11           7

# %%
# Conclusion
SR Waugh (AUS)
MN Samuels (WI)
MS Dhoni (Asia/INDIA)
SR Tendulkar (INDIA)
MG Bevan (AUS)
Yuvraj Singh (Asia/INDIA)
Shahid Afridi (Asia/ICC/PAK)
AB de Villiers (Afr/SA)
These are the best batsman according to our model building respectively.
